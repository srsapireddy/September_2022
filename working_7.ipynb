# %%
# Creating a model
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as k
from keras.utils.generic_utils import get_custom_objects
"""
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
"""

#r = tf.cond(tf.less(x, y), f1, f2)


@tf.function
def custom_activation(x):
  #def f1(): return k.tf.add(0.001,k.tf.add(x,7.5))
  def f3(): return k.tf.add(0.062,k.tf.multiply(tf.cast(x, tf.float32),0.011))
  def f5(): return k.tf.add(0.253,k.tf.multiply(tf.cast(x, tf.float32),0.072))
  def f7(): return k.tf.add(0.5,k.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f9(): return k.tf.add(0.866,k.tf.multiply(tf.cast(x, tf.float32),0.029))
  def f11(): return k.tf.add(0.973,k.tf.multiply(tf.cast(x, tf.float32),0.004))
  def f12(): return k.tf.ones([1,1],tf.float32)

  def f10(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 3), tf.less(tf.cast(x, tf.float32), 5)),x=f11(),y=f12())
  def f8(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 2), tf.less(tf.cast(x, tf.float32), 4)),x=f9(),y=f10())
  def f6(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -2), tf.less(tf.cast(x, tf.float32), 2)),x=f7(),y=f8())
  def f4(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -4), tf.less(tf.cast(x, tf.float32), -2)),x=f5(),y=f6())
  def f2(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -6), tf.less(tf.cast(x, tf.float32), -4)),x=f3(),y=f4())
  
  
  r = tf.where(
         condition=(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -10), tf.less(tf.cast(x, tf.float32), -6))),
         x=k.tf.add(0.001,k.tf.multiply(tf.cast(x, tf.float32),0.008)),
         y=f2()
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x))) 
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))): 
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x)) 
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config

# classifier loss, Adam optimizer, classifier accuracy
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 13s 22ms/step - loss: 2.2972 - accuracy: 0.1283 - val_loss: 2.2718 - val_accuracy: 0.1473
# Epoch 2/50
# 469/469 [==============================] - 10s 21ms/step - loss: 2.1392 - accuracy: 0.3735 - val_loss: 1.7877 - val_accuracy: 0.5907
# Epoch 3/50
# 469/469 [==============================] - 10s 21ms/step - loss: 1.1757 - accuracy: 0.7520 - val_loss: 0.7339 - val_accuracy: 0.8222
# Epoch 4/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.6193 - accuracy: 0.8397 - val_loss: 0.5053 - val_accuracy: 0.8645
# Epoch 5/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.4747 - accuracy: 0.8707 - val_loss: 0.4083 - val_accuracy: 0.8889
# Epoch 6/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.4014 - accuracy: 0.8884 - val_loss: 0.3531 - val_accuracy: 0.9023
# Epoch 7/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.3503 - accuracy: 0.9021 - val_loss: 0.3083 - val_accuracy: 0.9140
# Epoch 8/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.3094 - accuracy: 0.9138 - val_loss: 0.2759 - val_accuracy: 0.9222
# Epoch 9/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.2761 - accuracy: 0.9224 - val_loss: 0.2441 - val_accuracy: 0.9311
# Epoch 10/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.2484 - accuracy: 0.9309 - val_loss: 0.2219 - val_accuracy: 0.9382
# Epoch 11/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.2258 - accuracy: 0.9373 - val_loss: 0.2019 - val_accuracy: 0.9419
# Epoch 12/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.2051 - accuracy: 0.9427 - val_loss: 0.1829 - val_accuracy: 0.9462
# Epoch 13/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1862 - accuracy: 0.9482 - val_loss: 0.1632 - val_accuracy: 0.9527
# Epoch 14/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1695 - accuracy: 0.9525 - val_loss: 0.1488 - val_accuracy: 0.9561
# Epoch 15/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1559 - accuracy: 0.9560 - val_loss: 0.1401 - val_accuracy: 0.9607
# Epoch 16/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1449 - accuracy: 0.9590 - val_loss: 0.1283 - val_accuracy: 0.9616
# Epoch 17/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1351 - accuracy: 0.9619 - val_loss: 0.1209 - val_accuracy: 0.9647
# Epoch 18/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1273 - accuracy: 0.9641 - val_loss: 0.1125 - val_accuracy: 0.9679
# Epoch 19/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1207 - accuracy: 0.9659 - val_loss: 0.1054 - val_accuracy: 0.9699
# Epoch 20/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1143 - accuracy: 0.9674 - val_loss: 0.1003 - val_accuracy: 0.9706
# Epoch 21/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1094 - accuracy: 0.9684 - val_loss: 0.0973 - val_accuracy: 0.9711
# Epoch 22/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1042 - accuracy: 0.9701 - val_loss: 0.0922 - val_accuracy: 0.9731
# Epoch 23/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0999 - accuracy: 0.9706 - val_loss: 0.0895 - val_accuracy: 0.9737
# Epoch 24/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0966 - accuracy: 0.9718 - val_loss: 0.0880 - val_accuracy: 0.9743
# Epoch 25/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0939 - accuracy: 0.9723 - val_loss: 0.0850 - val_accuracy: 0.9739
# Epoch 26/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0911 - accuracy: 0.9736 - val_loss: 0.0827 - val_accuracy: 0.9743
# Epoch 27/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0883 - accuracy: 0.9744 - val_loss: 0.0815 - val_accuracy: 0.9753
# Epoch 28/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0859 - accuracy: 0.9748 - val_loss: 0.0776 - val_accuracy: 0.9765
# Epoch 29/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0839 - accuracy: 0.9754 - val_loss: 0.0766 - val_accuracy: 0.9766
# Epoch 30/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0814 - accuracy: 0.9763 - val_loss: 0.0733 - val_accuracy: 0.9773
# Epoch 31/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0798 - accuracy: 0.9769 - val_loss: 0.0723 - val_accuracy: 0.9772
# Epoch 32/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0777 - accuracy: 0.9771 - val_loss: 0.0703 - val_accuracy: 0.9774
# Epoch 33/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0757 - accuracy: 0.9780 - val_loss: 0.0685 - val_accuracy: 0.9773
# Epoch 34/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0738 - accuracy: 0.9783 - val_loss: 0.0675 - val_accuracy: 0.9790
# Epoch 35/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0727 - accuracy: 0.9785 - val_loss: 0.0668 - val_accuracy: 0.9786
# Epoch 36/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0706 - accuracy: 0.9790 - val_loss: 0.0665 - val_accuracy: 0.9787
# Epoch 37/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0693 - accuracy: 0.9794 - val_loss: 0.0639 - val_accuracy: 0.9802
# Epoch 38/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0682 - accuracy: 0.9801 - val_loss: 0.0630 - val_accuracy: 0.9792
# Epoch 39/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0669 - accuracy: 0.9807 - val_loss: 0.0622 - val_accuracy: 0.9804
# Epoch 40/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0659 - accuracy: 0.9804 - val_loss: 0.0624 - val_accuracy: 0.9803
# Epoch 41/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0650 - accuracy: 0.9808 - val_loss: 0.0611 - val_accuracy: 0.9808
# Epoch 42/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0636 - accuracy: 0.9813 - val_loss: 0.0601 - val_accuracy: 0.9805
# Epoch 43/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0627 - accuracy: 0.9817 - val_loss: 0.0606 - val_accuracy: 0.9814
# Epoch 44/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0616 - accuracy: 0.9821 - val_loss: 0.0588 - val_accuracy: 0.9810
# Epoch 45/50
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0605 - accuracy: 0.9821 - val_loss: 0.0585 - val_accuracy: 0.9805
# Epoch 46/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0600 - accuracy: 0.9824 - val_loss: 0.0574 - val_accuracy: 0.9812
# Epoch 47/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0593 - accuracy: 0.9824 - val_loss: 0.0575 - val_accuracy: 0.9813
# Epoch 48/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0588 - accuracy: 0.9826 - val_loss: 0.0570 - val_accuracy: 0.9816
# Epoch 49/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 0.0568 - val_accuracy: 0.9814
# Epoch 50/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0567 - accuracy: 0.9832 - val_loss: 0.0560 - val_accuracy: 0.9815
#
# Test accuracy: 98.2%
