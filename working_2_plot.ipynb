# %%
# Creating a model
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects
"""
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
"""

#r = tf.cond(tf.less(x, y), f1, f2)


@tf.function
def custom_activation(x):

  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -10), K.tf.less(tf.cast(x, tf.float32), 0))),
         x=K.tf.add(0.017,K.tf.multiply(0.002,tf.cast(x, tf.float32))),
         y=K.tf.add(0.803,K.tf.multiply(0.038,tf.cast(x, tf.float32)))
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x))) 
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))): 
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x)) 
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config

# classifier loss, Adam optimizer, classifier accuracy
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
history = model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 73s 153ms/step - loss: 2.1216 - accuracy: 0.3213 - val_loss: 1.9864 - val_accuracy: 0.3967
# Epoch 2/50
# 469/469 [==============================] - 66s 140ms/step - loss: 1.6601 - accuracy: 0.6105 - val_loss: 1.2868 - val_accuracy: 0.6992
# Epoch 3/50
# 469/469 [==============================] - 65s 140ms/step - loss: 1.1078 - accuracy: 0.7502 - val_loss: 0.8663 - val_accuracy: 0.7936
# Epoch 4/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.7735 - accuracy: 0.8028 - val_loss: 0.6547 - val_accuracy: 0.8269
# Epoch 5/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.6212 - accuracy: 0.8342 - val_loss: 0.5540 - val_accuracy: 0.8587
# Epoch 6/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.5329 - accuracy: 0.8541 - val_loss: 0.4834 - val_accuracy: 0.8650
# Epoch 7/50
# 469/469 [==============================] - 66s 142ms/step - loss: 0.4738 - accuracy: 0.8682 - val_loss: 0.4315 - val_accuracy: 0.8784
# Epoch 8/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.4334 - accuracy: 0.8768 - val_loss: 0.4029 - val_accuracy: 0.8852
# Epoch 9/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.4025 - accuracy: 0.8845 - val_loss: 0.3674 - val_accuracy: 0.8922
# Epoch 10/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3777 - accuracy: 0.8912 - val_loss: 0.3493 - val_accuracy: 0.8998
# Epoch 11/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3579 - accuracy: 0.8968 - val_loss: 0.3315 - val_accuracy: 0.9034
# Epoch 12/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.3429 - accuracy: 0.9008 - val_loss: 0.3227 - val_accuracy: 0.9082
# Epoch 13/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3274 - accuracy: 0.9048 - val_loss: 0.3033 - val_accuracy: 0.9122
# Epoch 14/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3175 - accuracy: 0.9070 - val_loss: 0.2937 - val_accuracy: 0.9152
# Epoch 15/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3081 - accuracy: 0.9100 - val_loss: 0.2826 - val_accuracy: 0.9183
# Epoch 16/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.3021 - accuracy: 0.9127 - val_loss: 0.2766 - val_accuracy: 0.9219
# Epoch 17/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.2867 - accuracy: 0.9168 - val_loss: 0.2676 - val_accuracy: 0.9234
# Epoch 18/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2904 - accuracy: 0.9161 - val_loss: 0.2661 - val_accuracy: 0.9233
# Epoch 19/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.2718 - accuracy: 0.9199 - val_loss: 0.2571 - val_accuracy: 0.9283
# Epoch 20/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2720 - accuracy: 0.9213 - val_loss: 0.2549 - val_accuracy: 0.9287
# Epoch 21/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.2584 - accuracy: 0.9247 - val_loss: 0.2368 - val_accuracy: 0.9327
# Epoch 22/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.2549 - accuracy: 0.9240 - val_loss: 0.2499 - val_accuracy: 0.9307
# Epoch 23/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2528 - accuracy: 0.9261 - val_loss: 0.2305 - val_accuracy: 0.9343
# Epoch 24/50
# 469/469 [==============================] - 65s 140ms/step - loss: 0.2456 - accuracy: 0.9283 - val_loss: 0.2236 - val_accuracy: 0.9340
# Epoch 25/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.2368 - accuracy: 0.9306 - val_loss: 0.2207 - val_accuracy: 0.9360
# Epoch 26/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.2276 - accuracy: 0.9340 - val_loss: 0.2203 - val_accuracy: 0.9380
# Epoch 27/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2272 - accuracy: 0.9337 - val_loss: 0.2070 - val_accuracy: 0.9393
# Epoch 28/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2177 - accuracy: 0.9361 - val_loss: 0.1995 - val_accuracy: 0.9426
# Epoch 29/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2122 - accuracy: 0.9380 - val_loss: 0.2016 - val_accuracy: 0.9408
# Epoch 30/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2126 - accuracy: 0.9376 - val_loss: 0.2021 - val_accuracy: 0.9413
# Epoch 31/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2086 - accuracy: 0.9400 - val_loss: 0.1935 - val_accuracy: 0.9459
# Epoch 32/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.2038 - accuracy: 0.9403 - val_loss: 0.1905 - val_accuracy: 0.9453
# Epoch 33/50
# 469/469 [==============================] - 66s 142ms/step - loss: 0.1995 - accuracy: 0.9430 - val_loss: 0.1866 - val_accuracy: 0.9463
# Epoch 34/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1905 - accuracy: 0.9439 - val_loss: 0.1801 - val_accuracy: 0.9501
# Epoch 35/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1895 - accuracy: 0.9459 - val_loss: 0.1779 - val_accuracy: 0.9500
# Epoch 36/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1881 - accuracy: 0.9464 - val_loss: 0.1782 - val_accuracy: 0.9501
# Epoch 37/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1846 - accuracy: 0.9472 - val_loss: 0.1707 - val_accuracy: 0.9505
# Epoch 38/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1781 - accuracy: 0.9488 - val_loss: 0.1658 - val_accuracy: 0.9542
# Epoch 39/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1739 - accuracy: 0.9503 - val_loss: 0.1654 - val_accuracy: 0.9526
# Epoch 40/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1717 - accuracy: 0.9498 - val_loss: 0.1589 - val_accuracy: 0.9555
# Epoch 41/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1716 - accuracy: 0.9514 - val_loss: 0.1563 - val_accuracy: 0.9565
# Epoch 42/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1652 - accuracy: 0.9530 - val_loss: 0.1527 - val_accuracy: 0.9558
# Epoch 43/50
# 469/469 [==============================] - 65s 140ms/step - loss: 0.1648 - accuracy: 0.9533 - val_loss: 0.1548 - val_accuracy: 0.9576
# Epoch 44/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1611 - accuracy: 0.9543 - val_loss: 0.1498 - val_accuracy: 0.9586
# Epoch 45/50
# 469/469 [==============================] - 65s 139ms/step - loss: 0.1559 - accuracy: 0.9555 - val_loss: 0.1462 - val_accuracy: 0.9573
# Epoch 46/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1547 - accuracy: 0.9562 - val_loss: 0.1427 - val_accuracy: 0.9595
# Epoch 47/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1524 - accuracy: 0.9570 - val_loss: 0.1437 - val_accuracy: 0.9599
# Epoch 48/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1506 - accuracy: 0.9571 - val_loss: 0.1418 - val_accuracy: 0.9614
# Epoch 49/50
# 469/469 [==============================] - 66s 141ms/step - loss: 0.1481 - accuracy: 0.9577 - val_loss: 0.1455 - val_accuracy: 0.9591
# Epoch 50/50
# 469/469 [==============================] - 66s 140ms/step - loss: 0.1465 - accuracy: 0.9575 - val_loss: 0.1390 - val_accuracy: 0.9594
#
# Test accuracy: 95.9%

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(2,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.ylim([0,2])
# Out:
# (0.0, 2.0)
